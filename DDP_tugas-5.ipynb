# %%
kendaraan = ['beat', 'motor', 200, 'pink', '2']
print(kendaraan)

kendaraan.append('13JT')
kendaraan.append('matik')
print(kendaraan)

kendaraan.insert(2, 'honda')
print(kendaraan)
# Out:
# ['beat', 'motor', 200, 'pink', '2']
# ['beat', 'motor', 200, 'pink', '2', '13JT', 'matik']
# ['beat', 'motor', 'honda', 200, 'pink', '2', '13JT', 'matik']

# %%
hitung_luas = int(input("""pilih salah satu:

1. Hitung luas persegi
2. Hitung luas lingkaran
3. hitung luas segitiga
"""))

match hitung_luas:
    case 1:
       print("maka hitung luas persegi")
       sisi = float(input("masukan nilai sisi: "))
       hitung_luas_persegi = sisi**2
       print(f"jadi luas persegi dengan sisi {sisi} cm adalah {hitung_luas_persegi}cm^2")
    case 2:
       print("Maka hitung luas lingkaran")
       jari_jari = float(input("Masukkan nilai jari-jari: "))
       hitung_luas_lingkaran = 3.14 * jari_jari * jari_jari
       print(f"Jadi luas lingkaran dengan jari-jari {jari_jari} cm adalah {hitung_luas_lingkaran} cm^2")
    case 3:
       print("Maka hitung luas segitiga")
       alas = float(input("Masukkan panjang alas: "))
       tinggi = float(input("Masukkan tinggi: "))
       luas_segitiga = 0.5 * alas * tinggi
       print(f"Luas segitiga dengan alas {alas} cm dan tinggi {tinggi} cm adalah {luas_segitiga} cm^2")

    case _:
      print('pilihan tidak valid')
# Out:
# pilih salah satu:
#
# 1. Hitung luas persegi
# 2. Hitung luas lingkaran
# 3. hitung luas segitiga
# 1
# maka hitung luas persegi
# masukan nilai sisi: 10
# jadi luas persegi dengan sisi 10.0 cm adalah 100.0cm^2
